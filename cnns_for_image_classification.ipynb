# %% [markdown]
# <a href="https://colab.research.google.com/github/Mamsheikh/cnn-image-classif/blob/master/cnns_for_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
#Visualize the first 26 images of the dataset

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
# model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0817 08:36:46.206698 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0817 08:36:46.239368 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0817 08:36:46.245020 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0817 08:36:46.281420 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0817 08:36:46.283897 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0817 08:36:46.292988 139672426309504 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,658,746
# Trainable params: 1,658,746
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
# Out:
# W0817 08:36:46.403325 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0817 08:36:46.426758 139672426309504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# W0817 08:36:46.541138 139672426309504 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 15s - loss: 1.4914 - acc: 0.4609 - val_loss: 1.2208 - val_acc: 0.5672
#
# Epoch 00001: val_loss improved from inf to 1.22083, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 8s - loss: 1.1009 - acc: 0.6127 - val_loss: 1.0906 - val_acc: 0.6224
#
# Epoch 00002: val_loss improved from 1.22083 to 1.09055, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 8s - loss: 0.9830 - acc: 0.6597 - val_loss: 0.9218 - val_acc: 0.6880
#
# Epoch 00003: val_loss improved from 1.09055 to 0.92175, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 8s - loss: 0.9323 - acc: 0.6798 - val_loss: 0.8627 - val_acc: 0.7146
#
# Epoch 00004: val_loss improved from 0.92175 to 0.86272, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 8s - loss: 0.9209 - acc: 0.6895 - val_loss: 0.8999 - val_acc: 0.7048
#
# Epoch 00005: val_loss did not improve from 0.86272
# Epoch 6/100
#  - 8s - loss: 0.9443 - acc: 0.6869 - val_loss: 0.8869 - val_acc: 0.6996
#
# Epoch 00006: val_loss did not improve from 0.86272
# Epoch 7/100
#  - 8s - loss: 0.9656 - acc: 0.6818 - val_loss: 1.0571 - val_acc: 0.6284
#
# Epoch 00007: val_loss did not improve from 0.86272
# Epoch 8/100
#  - 8s - loss: 1.0017 - acc: 0.6736 - val_loss: 1.1533 - val_acc: 0.6712
#
# Epoch 00008: val_loss did not improve from 0.86272
# Epoch 9/100
#  - 8s - loss: 1.0272 - acc: 0.6687 - val_loss: 1.1515 - val_acc: 0.6788
#
# Epoch 00009: val_loss did not improve from 0.86272
# Epoch 10/100
#  - 8s - loss: 1.0531 - acc: 0.6592 - val_loss: 1.1439 - val_acc: 0.6226
#
# Epoch 00010: val_loss did not improve from 0.86272
# Epoch 11/100
#  - 8s - loss: 1.1024 - acc: 0.6492 - val_loss: 1.0914 - val_acc: 0.6678
#
# Epoch 00011: val_loss did not improve from 0.86272
# Epoch 12/100
#  - 8s - loss: 1.1181 - acc: 0.6418 - val_loss: 1.0036 - val_acc: 0.6906
#
# Epoch 00012: val_loss did not improve from 0.86272
# Epoch 13/100
#  - 8s - loss: 1.1399 - acc: 0.6365 - val_loss: 1.0438 - val_acc: 0.6446
#
# Epoch 00013: val_loss did not improve from 0.86272
# Epoch 14/100
#  - 8s - loss: 1.1553 - acc: 0.6292 - val_loss: 1.6097 - val_acc: 0.5732
#
# Epoch 00014: val_loss did not improve from 0.86272
# Epoch 15/100
#  - 8s - loss: 1.1681 - acc: 0.6258 - val_loss: 1.3354 - val_acc: 0.6116
#
# Epoch 00015: val_loss did not improve from 0.86272
# Epoch 16/100
#  - 8s - loss: 1.2038 - acc: 0.6173 - val_loss: 1.3952 - val_acc: 0.6278
#
# Epoch 00016: val_loss did not improve from 0.86272
# Epoch 17/100
#  - 8s - loss: 1.2284 - acc: 0.6069 - val_loss: 1.1254 - val_acc: 0.6382
#
# Epoch 00017: val_loss did not improve from 0.86272
# Epoch 18/100
#  - 8s - loss: 1.2407 - acc: 0.6043 - val_loss: 1.1751 - val_acc: 0.6218
#
# Epoch 00018: val_loss did not improve from 0.86272
# Epoch 19/100
#  - 8s - loss: 1.2716 - acc: 0.5931 - val_loss: 1.2496 - val_acc: 0.5716
#
# Epoch 00019: val_loss did not improve from 0.86272
# Epoch 20/100
#  - 8s - loss: 1.2842 - acc: 0.5893 - val_loss: 1.2210 - val_acc: 0.6158
#
# Epoch 00020: val_loss did not improve from 0.86272
# Epoch 21/100
#  - 8s - loss: 1.3223 - acc: 0.5783 - val_loss: 3.2472 - val_acc: 0.4758
#
# Epoch 00021: val_loss did not improve from 0.86272
# Epoch 22/100
#  - 8s - loss: 1.3512 - acc: 0.5685 - val_loss: 1.5572 - val_acc: 0.4574
#
# Epoch 00022: val_loss did not improve from 0.86272
# Epoch 23/100
#  - 8s - loss: 1.3673 - acc: 0.5654 - val_loss: 1.2667 - val_acc: 0.5950
#
# Epoch 00023: val_loss did not improve from 0.86272
# Epoch 24/100
#  - 8s - loss: 1.3835 - acc: 0.5588 - val_loss: 1.2011 - val_acc: 0.5992
#
# Epoch 00024: val_loss did not improve from 0.86272
# Epoch 25/100
#  - 8s - loss: 1.4055 - acc: 0.5500 - val_loss: 1.6812 - val_acc: 0.5402
#
# Epoch 00025: val_loss did not improve from 0.86272
# Epoch 26/100
#  - 8s - loss: 1.4185 - acc: 0.5446 - val_loss: 1.1642 - val_acc: 0.6102
#
# Epoch 00026: val_loss did not improve from 0.86272
# Epoch 27/100
#  - 8s - loss: 1.4551 - acc: 0.5332 - val_loss: 3.3988 - val_acc: 0.4684
#
# Epoch 00027: val_loss did not improve from 0.86272
# Epoch 28/100
#  - 8s - loss: 1.4693 - acc: 0.5246 - val_loss: 1.2085 - val_acc: 0.5902
#
# Epoch 00028: val_loss did not improve from 0.86272
# Epoch 29/100
#  - 9s - loss: 1.4848 - acc: 0.5209 - val_loss: 1.6668 - val_acc: 0.4430
#
# Epoch 00029: val_loss did not improve from 0.86272
# Epoch 30/100
#  - 8s - loss: 1.5162 - acc: 0.5046 - val_loss: 1.3224 - val_acc: 0.5222
#
# Epoch 00030: val_loss did not improve from 0.86272
# Epoch 31/100
#  - 8s - loss: 1.5545 - acc: 0.4950 - val_loss: 1.2628 - val_acc: 0.5706
#
# Epoch 00031: val_loss did not improve from 0.86272
# Epoch 32/100
#  - 8s - loss: 1.5761 - acc: 0.4777 - val_loss: 1.5188 - val_acc: 0.4622
#
# Epoch 00032: val_loss did not improve from 0.86272
# Epoch 33/100
#  - 8s - loss: 1.6160 - acc: 0.4731 - val_loss: 1.4554 - val_acc: 0.4650
#
# Epoch 00033: val_loss did not improve from 0.86272
# Epoch 34/100
#  - 8s - loss: 1.5959 - acc: 0.4793 - val_loss: 1.7904 - val_acc: 0.4326
#
# Epoch 00034: val_loss did not improve from 0.86272
# Epoch 35/100
#  - 8s - loss: 1.6082 - acc: 0.4766 - val_loss: 2.6467 - val_acc: 0.4984
#
# Epoch 00035: val_loss did not improve from 0.86272
# Epoch 36/100
#  - 8s - loss: 1.6309 - acc: 0.4644 - val_loss: 1.4503 - val_acc: 0.5204
#
# Epoch 00036: val_loss did not improve from 0.86272
# Epoch 37/100
#  - 8s - loss: 1.6357 - acc: 0.4616 - val_loss: 1.7098 - val_acc: 0.3972
#
# Epoch 00037: val_loss did not improve from 0.86272
# Epoch 38/100
#  - 8s - loss: 1.6584 - acc: 0.4562 - val_loss: 1.5029 - val_acc: 0.4900
#
# Epoch 00038: val_loss did not improve from 0.86272
# Epoch 39/100
#  - 8s - loss: 1.6512 - acc: 0.4527 - val_loss: 2.1169 - val_acc: 0.2888
#
# Epoch 00039: val_loss did not improve from 0.86272
# Epoch 40/100
#  - 8s - loss: 1.6432 - acc: 0.4535 - val_loss: 1.4296 - val_acc: 0.5130
#
# Epoch 00040: val_loss did not improve from 0.86272
# Epoch 41/100
#  - 8s - loss: 1.6723 - acc: 0.4424 - val_loss: 1.5742 - val_acc: 0.4194
#
# Epoch 00041: val_loss did not improve from 0.86272
# Epoch 42/100
#  - 8s - loss: 1.6928 - acc: 0.4387 - val_loss: 1.4375 - val_acc: 0.5148
#
# Epoch 00042: val_loss did not improve from 0.86272
# Epoch 43/100
#  - 8s - loss: 1.7179 - acc: 0.4358 - val_loss: 1.5233 - val_acc: 0.4842
#
# Epoch 00043: val_loss did not improve from 0.86272
# Epoch 44/100
#  - 8s - loss: 1.7032 - acc: 0.4352 - val_loss: 1.5300 - val_acc: 0.4712
#
# Epoch 00044: val_loss did not improve from 0.86272
# Epoch 45/100
#  - 8s - loss: 1.7374 - acc: 0.4162 - val_loss: 1.8441 - val_acc: 0.3174
#
# Epoch 00045: val_loss did not improve from 0.86272
# Epoch 46/100
#  - 8s - loss: 1.7558 - acc: 0.4085 - val_loss: 2.0922 - val_acc: 0.4438
#
# Epoch 00046: val_loss did not improve from 0.86272
# Epoch 47/100
#  - 8s - loss: 1.7513 - acc: 0.4100 - val_loss: 1.4071 - val_acc: 0.5032
#
# Epoch 00047: val_loss did not improve from 0.86272
# Epoch 48/100
#  - 8s - loss: 1.7421 - acc: 0.4110 - val_loss: 1.6909 - val_acc: 0.3856
#
# Epoch 00048: val_loss did not improve from 0.86272
# Epoch 49/100
#  - 8s - loss: 1.7546 - acc: 0.4058 - val_loss: 1.3924 - val_acc: 0.5170
#
# Epoch 00049: val_loss did not improve from 0.86272
# Epoch 50/100
#  - 8s - loss: 1.7700 - acc: 0.4030 - val_loss: 1.4672 - val_acc: 0.4780
#
# Epoch 00050: val_loss did not improve from 0.86272
# Epoch 51/100
#  - 8s - loss: 1.7787 - acc: 0.3951 - val_loss: 1.7242 - val_acc: 0.3470
#
# Epoch 00051: val_loss did not improve from 0.86272
# Epoch 52/100
#  - 8s - loss: 1.7982 - acc: 0.3882 - val_loss: 1.7071 - val_acc: 0.3928
#
# Epoch 00052: val_loss did not improve from 0.86272
# Epoch 53/100
#  - 8s - loss: 1.7996 - acc: 0.3897 - val_loss: 1.4876 - val_acc: 0.5048
#
# Epoch 00053: val_loss did not improve from 0.86272
# Epoch 54/100
#  - 8s - loss: 1.8304 - acc: 0.3730 - val_loss: 1.8025 - val_acc: 0.3118
#
# Epoch 00054: val_loss did not improve from 0.86272
# Epoch 55/100
#  - 8s - loss: 1.8650 - acc: 0.3571 - val_loss: 1.8169 - val_acc: 0.3340
#
# Epoch 00055: val_loss did not improve from 0.86272
# Epoch 56/100
#  - 8s - loss: 1.8822 - acc: 0.3557 - val_loss: 1.6994 - val_acc: 0.4304
#
# Epoch 00056: val_loss did not improve from 0.86272
# Epoch 57/100
#  - 8s - loss: 1.8994 - acc: 0.3448 - val_loss: 2.0742 - val_acc: 0.2074
#
# Epoch 00057: val_loss did not improve from 0.86272
# Epoch 58/100
#  - 8s - loss: 1.9275 - acc: 0.3388 - val_loss: 1.9595 - val_acc: 0.3432
#
# Epoch 00058: val_loss did not improve from 0.86272
# Epoch 59/100
#  - 8s - loss: 1.9680 - acc: 0.3241 - val_loss: 1.9569 - val_acc: 0.3096
#
# Epoch 00059: val_loss did not improve from 0.86272
# Epoch 60/100
#  - 8s - loss: 1.9648 - acc: 0.3197 - val_loss: 1.7859 - val_acc: 0.3220
#
# Epoch 00060: val_loss did not improve from 0.86272
# Epoch 61/100
#  - 8s - loss: 2.0107 - acc: 0.2996 - val_loss: 1.8632 - val_acc: 0.3236
#
# Epoch 00061: val_loss did not improve from 0.86272
# Epoch 62/100
#  - 8s - loss: 2.0138 - acc: 0.2971 - val_loss: 1.8382 - val_acc: 0.3146
#
# Epoch 00062: val_loss did not improve from 0.86272
# Epoch 63/100
#  - 8s - loss: 2.0118 - acc: 0.2953 - val_loss: 1.7028 - val_acc: 0.3648
#
# Epoch 00063: val_loss did not improve from 0.86272
# Epoch 64/100
#  - 8s - loss: 2.0174 - acc: 0.2896 - val_loss: 1.9804 - val_acc: 0.2308
#
# Epoch 00064: val_loss did not improve from 0.86272
# Epoch 65/100
#  - 8s - loss: 2.0140 - acc: 0.2872 - val_loss: 2.2563 - val_acc: 0.1404
#
# Epoch 00065: val_loss did not improve from 0.86272
# Epoch 66/100
#  - 8s - loss: 2.0041 - acc: 0.2899 - val_loss: 1.9044 - val_acc: 0.2858
#
# Epoch 00066: val_loss did not improve from 0.86272
# Epoch 67/100
#  - 8s - loss: 2.0515 - acc: 0.2768 - val_loss: 2.1004 - val_acc: 0.2004
#
# Epoch 00067: val_loss did not improve from 0.86272
# Epoch 68/100
#  - 8s - loss: 2.0644 - acc: 0.2699 - val_loss: 2.1810 - val_acc: 0.1558
#
# Epoch 00068: val_loss did not improve from 0.86272
# Epoch 69/100
#  - 8s - loss: 2.0981 - acc: 0.2586 - val_loss: 1.8201 - val_acc: 0.3344
#
# Epoch 00069: val_loss did not improve from 0.86272
# Epoch 70/100
#  - 8s - loss: 2.0948 - acc: 0.2493 - val_loss: 2.1662 - val_acc: 0.1852
#
# Epoch 00070: val_loss did not improve from 0.86272
# Epoch 71/100
#  - 8s - loss: 2.1079 - acc: 0.2480 - val_loss: 1.9443 - val_acc: 0.2598
#
# Epoch 00071: val_loss did not improve from 0.86272
# Epoch 72/100
#  - 8s - loss: 2.0649 - acc: 0.2536 - val_loss: 1.9371 - val_acc: 0.2710
#
# Epoch 00072: val_loss did not improve from 0.86272
# Epoch 73/100
#  - 8s - loss: 2.1055 - acc: 0.2412 - val_loss: 2.1137 - val_acc: 0.2148
#
# Epoch 00073: val_loss did not improve from 0.86272
# Epoch 74/100
#  - 8s - loss: 2.1343 - acc: 0.2319 - val_loss: 2.1412 - val_acc: 0.1968
#
# Epoch 00074: val_loss did not improve from 0.86272
# Epoch 75/100
#  - 8s - loss: 2.1362 - acc: 0.2291 - val_loss: 1.8963 - val_acc: 0.3068
#
# Epoch 00075: val_loss did not improve from 0.86272
# Epoch 76/100
#  - 8s - loss: 2.1342 - acc: 0.2270 - val_loss: 2.0945 - val_acc: 0.2070
#
# Epoch 00076: val_loss did not improve from 0.86272
# Epoch 77/100
#  - 8s - loss: 2.1226 - acc: 0.2283 - val_loss: 1.9960 - val_acc: 0.2500
#
# Epoch 00077: val_loss did not improve from 0.86272
# Epoch 78/100
#  - 8s - loss: 2.1378 - acc: 0.2248 - val_loss: 1.8423 - val_acc: 0.2980
#
# Epoch 00078: val_loss did not improve from 0.86272
# Epoch 79/100
#  - 8s - loss: 2.1588 - acc: 0.2067 - val_loss: 2.0468 - val_acc: 0.2286
#
# Epoch 00079: val_loss did not improve from 0.86272
# Epoch 80/100
#  - 8s - loss: 2.1484 - acc: 0.2069 - val_loss: 1.8933 - val_acc: 0.2556
#
# Epoch 00080: val_loss did not improve from 0.86272
# Epoch 81/100
#  - 8s - loss: 2.1344 - acc: 0.2043 - val_loss: 2.4007 - val_acc: 0.2558
#
# Epoch 00081: val_loss did not improve from 0.86272
# Epoch 82/100
#  - 8s - loss: 2.1681 - acc: 0.2036 - val_loss: 2.6616 - val_acc: 0.2098
#
# Epoch 00082: val_loss did not improve from 0.86272
# Epoch 83/100
#  - 8s - loss: 2.1883 - acc: 0.1947 - val_loss: 2.2198 - val_acc: 0.1576
#
# Epoch 00083: val_loss did not improve from 0.86272
# Epoch 84/100
#  - 8s - loss: 2.1734 - acc: 0.1921 - val_loss: 1.9509 - val_acc: 0.2492
#
# Epoch 00084: val_loss did not improve from 0.86272
# Epoch 85/100
#  - 8s - loss: 2.1905 - acc: 0.1966 - val_loss: 2.0967 - val_acc: 0.1682
#
# Epoch 00085: val_loss did not improve from 0.86272
# Epoch 86/100
#  - 8s - loss: 2.2253 - acc: 0.1849 - val_loss: 1.9250 - val_acc: 0.3018
#
# Epoch 00086: val_loss did not improve from 0.86272
# Epoch 87/100
#  - 8s - loss: 2.2356 - acc: 0.1892 - val_loss: 2.0411 - val_acc: 0.2532
#
# Epoch 00087: val_loss did not improve from 0.86272
# Epoch 88/100
#  - 8s - loss: 2.2441 - acc: 0.1841 - val_loss: 2.2088 - val_acc: 0.1688
#
# Epoch 00088: val_loss did not improve from 0.86272
# Epoch 89/100
#  - 8s - loss: 2.2460 - acc: 0.1738 - val_loss: 2.0564 - val_acc: 0.2066
#
# Epoch 00089: val_loss did not improve from 0.86272
# Epoch 90/100
#  - 8s - loss: 2.2744 - acc: 0.1682 - val_loss: 2.0910 - val_acc: 0.1746
#
# Epoch 00090: val_loss did not improve from 0.86272
# Epoch 91/100
#  - 8s - loss: 2.2721 - acc: 0.1656 - val_loss: 2.2003 - val_acc: 0.1450
#
# Epoch 00091: val_loss did not improve from 0.86272
# Epoch 92/100
#  - 8s - loss: 2.2809 - acc: 0.1584 - val_loss: 2.1106 - val_acc: 0.1670
#
# Epoch 00092: val_loss did not improve from 0.86272
# Epoch 93/100
#  - 8s - loss: 2.2740 - acc: 0.1516 - val_loss: 2.1328 - val_acc: 0.1742
#
# Epoch 00093: val_loss did not improve from 0.86272
# Epoch 94/100
#  - 8s - loss: 2.2557 - acc: 0.1576 - val_loss: 2.0738 - val_acc: 0.1772
#
# Epoch 00094: val_loss did not improve from 0.86272
# Epoch 95/100
#  - 8s - loss: 2.2943 - acc: 0.1575 - val_loss: 2.1065 - val_acc: 0.1818
#
# Epoch 00095: val_loss did not improve from 0.86272
# Epoch 96/100
#  - 8s - loss: 2.2428 - acc: 0.1567 - val_loss: 2.1585 - val_acc: 0.1686
#
# Epoch 00096: val_loss did not improve from 0.86272
# Epoch 97/100
#  - 8s - loss: 2.2725 - acc: 0.1580 - val_loss: 2.0822 - val_acc: 0.1746
#
# Epoch 00097: val_loss did not improve from 0.86272
# Epoch 98/100
#  - 8s - loss: 2.2369 - acc: 0.1522 - val_loss: 2.0464 - val_acc: 0.1958
#
# Epoch 00098: val_loss did not improve from 0.86272
# Epoch 99/100
#  - 8s - loss: 2.2381 - acc: 0.1549 - val_loss: 2.1507 - val_acc: 0.1806
#
# Epoch 00099: val_loss did not improve from 0.86272
# Epoch 100/100
#  - 8s - loss: 2.2390 - acc: 0.1570 - val_loss: 2.0393 - val_acc: 0.1840
#
# Epoch 00100: val_loss did not improve from 0.86272

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7026

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
